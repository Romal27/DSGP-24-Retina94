# %% [markdown]
# ### Imports

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Defining paths and loading the 3 csv files

# %%
train_image_folder_path = '/Users/teransenevirathne/Desktop/DSGP-24-Retina94/Dataset/train_images/train_images'
test_image_folder_path = '/Users/teransenevirathne/Desktop/DSGP-24-Retina94/Dataset/test_images/test_images'
val_image_folder_path = '/Users/teransenevirathne/Desktop/DSGP-24-Retina94/Dataset/val_images/val_images'

train_csv_path = '/Users/teransenevirathne/Desktop/DSGP-24-Retina94/Dataset/train.csv'
test_csv_path = '/Users/teransenevirathne/Desktop/DSGP-24-Retina94/Dataset/test.csv'
val_csv_path = '/Users/teransenevirathne/Desktop/DSGP-24-Retina94/Dataset/valid.csv'

train_data = pd.read_csv(train_csv_path)
val_data = pd.read_csv(val_csv_path)
test_data = pd.read_csv(test_csv_path)

# %% [markdown]
# ### Checking for missing images in train set

# %%
train_missing_images = []
for image_id in train_data['id_code']:
    image_filename = image_id + ".png"
    image_path = os.path.join(train_image_folder_path, image_filename)
    if not os.path.exists(image_path):
        train_missing_images.append(image_id)
print("Total Images in Train Folder:", len(os.listdir(train_image_folder_path)))
print("Total Images in Train CSV:", len(train_data))
print("Missing Images in Train Dataset:", len(train_missing_images))
if len(train_missing_images) > 0:
    print("Missing Images:", train_missing_images)
# Out:
# Total Images in Train Folder: 2930
# Total Images in Train CSV: 2930
# Missing Images in Train Dataset: 0

# %% [markdown]
# ### Checking for missing images in test set

# %%
test_missing_images = []
for image_id in test_data['id_code']:
    image_filename = image_id + ".png"
    image_path = os.path.join(test_image_folder_path, image_filename)
    if not os.path.exists(image_path):
        test_missing_images.append(image_id)
print("Total Images in Test Folder:", len(os.listdir(test_image_folder_path)))
print("Total Images in Test CSV:", len(test_data))
print("Missing Images in Test Dataset:", len(test_missing_images))
if len(test_missing_images) > 0:
    print("Missing Images:", test_missing_images)
# Out:
# Total Images in Test Folder: 366
# Total Images in Test CSV: 366
# Missing Images in Test Dataset: 0

# %% [markdown]
# ### Checking for missing images in validation set

# %%
validation_missing_images = []
for image_id in val_data['id_code']:
    image_filename = image_id + ".png"
    image_path = os.path.join(val_image_folder_path, image_filename)
    if not os.path.exists(image_path):
        validation_missing_images.append(image_id)
print("Total Images in Validation Folder:", len(os.listdir(val_image_folder_path)))
print("Total Images in Validation CSV:", len(val_data))
print("Missing Images in Validation Dataset:", len(validation_missing_images))
if len(validation_missing_images) > 0:
    print("Missing Images:", validation_missing_images)
# Out:
# Total Images in Validation Folder: 366
# Total Images in Validation CSV: 366
# Missing Images in Validation Dataset: 0

# %% [markdown]
# ### How the dataset is split into train, test and validation

# %%
split_counts = [len(train_data), len(val_data), len(test_data)]
labels = ["Train", "Validation", "Test"]
plt.figure(figsize=(6, 4))
plt.pie(split_counts, labels=labels, autopct="%1.1f%%", startangle=90)
plt.title("Percentage Distribution of Dataset Splits")
plt.show()

# %% [markdown]
# ### Analysis of Train Dataset

# %%
print("\nDataset Information:")
train_data.info()

print("\nFirst Five Rows of the Dataset:")
print(train_data.head())

train_label_distribution = train_data['diagnosis'].value_counts().sort_index()
plt.figure(figsize=(8, 6))
plt.bar(train_label_distribution.index, train_label_distribution.values, color='skyblue')
plt.title("Distribution of Diabetic Retinopathy Stages (Train Dataset)")
plt.xlabel("Diagnosis (DR Stage)")
plt.ylabel("Count")
plt.xticks([0, 1, 2, 3, 4], ["No DR", "Mild DR", "Moderate DR", "Severe DR", "Proliferative DR"])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

print("\nLabel Distribution:")
print(train_label_distribution)

print("\nMissing Values in Dataset:")
print(train_data.isnull().sum())

train_label_distribution = train_data['diagnosis'].value_counts().sort_index()
plt.figure(figsize=(6, 4))
plt.pie(train_label_distribution.values, labels=["No DR", "Mild DR", "Moderate DR", "Severe DR", "Proliferative DR"], autopct="%1.1f%%", startangle=90)
plt.title("Percentage Distribution of Diabetic Retinopathy Stages (Train Dataset)")
plt.show()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id_code    2930 non-null   object
#  1   diagnosis  2930 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 45.9+ KB
#
# First Five Rows of the Dataset:
#         id_code  diagnosis
# 0  1ae8c165fd53          2
# 1  1b329a127307          1
# 2  1b32e1d775ea          4
# 3  1b3647865779          0
# 4  1b398c0494d1          0
# Label Distribution:
# diagnosis
# 0    1434
# 1     300
# 2     808
# 3     154
# 4     234
# Name: count, dtype: int64
#
# Missing Values in Dataset:
# id_code      0
# diagnosis    0
# dtype: int64

# %% [markdown]
# ### Analysis of Test Dataset

# %%
print("\nDataset Information:")
test_data.info()

print("\nFirst Five Rows of the Dataset:")
print(test_data.head())

test_label_distribution = test_data['diagnosis'].value_counts().sort_index()
plt.figure(figsize=(8, 6))
plt.bar(test_label_distribution.index, test_label_distribution.values, color='skyblue')
plt.title("Distribution of Diabetic Retinopathy Stages (Test Dataset)")
plt.xlabel("Diagnosis (DR Stage)")
plt.ylabel("Count")
plt.xticks([0, 1, 2, 3, 4], ["No DR", "Mild DR", "Moderate DR", "Severe DR", "Proliferative DR"])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

print("\nLabel Distribution:")
print(test_label_distribution)

print("\nMissing Values in Dataset:")
print(test_data.isnull().sum())

test_label_distribution = test_data['diagnosis'].value_counts().sort_index()
plt.figure(figsize=(6, 4))
plt.pie(test_label_distribution.values, labels=["No DR", "Mild DR", "Moderate DR", "Severe DR", "Proliferative DR"], autopct="%1.1f%%", startangle=90)
plt.title("Percentage Distribution of Diabetic Retinopathy Stages (Test Dataset)")
plt.show()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id_code    366 non-null    object
#  1   diagnosis  366 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB
#
# First Five Rows of the Dataset:
#         id_code  diagnosis
# 0  e4dcca36ceb4          0
# 1  e4e343eaae2a          2
# 2  e4f12411fd85          4
# 3  e50b0174690d          0
# 4  e5197d77ec68          0
# Label Distribution:
# diagnosis
# 0    199
# 1     30
# 2     87
# 3     17
# 4     33
# Name: count, dtype: int64
#
# Missing Values in Dataset:
# id_code      0
# diagnosis    0
# dtype: int64

# %% [markdown]
# ### Analysis of Validation Dataset

# %%
print("\nDataset Information:")
val_data.info()

print("\nFirst Five Rows of the Dataset:")
print(val_data.head())

val_label_distribution = val_data['diagnosis'].value_counts().sort_index()
plt.figure(figsize=(8, 6))
plt.bar(val_label_distribution.index, val_label_distribution.values, color='skyblue')
plt.title("Distribution of Diabetic Retinopathy Stages (Validation Dataset)")
plt.xlabel("Diagnosis (DR Stage)")
plt.ylabel("Count")
plt.xticks([0, 1, 2, 3, 4], ["No DR", "Mild DR", "Moderate DR", "Severe DR", "Proliferative DR"])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

print("\nLabel Distribution:")
print(val_label_distribution)

print("\nMissing Values in Dataset:")
print(val_data.isnull().sum())

val_label_distribution = val_data['diagnosis'].value_counts().sort_index()
plt.figure(figsize=(6, 4))
plt.pie(val_label_distribution.values, labels=["No DR", "Mild DR", "Moderate DR", "Severe DR", "Proliferative DR"], autopct="%1.1f%%", startangle=90)
plt.title("Percentage Distribution of Diabetic Retinopathy Stages (Validation Dataset)")
plt.show()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id_code    366 non-null    object
#  1   diagnosis  366 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB
#
# First Five Rows of the Dataset:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0
# Label Distribution:
# diagnosis
# 0    172
# 1     40
# 2    104
# 3     22
# 4     28
# Name: count, dtype: int64
#
# Missing Values in Dataset:
# id_code      0
# diagnosis    0
# dtype: int64

# %% [markdown]
# ## Combined Analysis of the whole dataset

# %%
combined_data = pd.concat([train_data, val_data, test_data], ignore_index=True)

print("\nDataset Information:")
combined_data.info()

print("\nFirst Five Rows of the Dataset:")
print(combined_data.head())

combined_label_distribution = combined_data['diagnosis'].value_counts().sort_index()
plt.figure(figsize=(8, 6))
plt.bar(combined_label_distribution.index, combined_label_distribution.values, color='skyblue')
plt.title("Distribution of Diabetic Retinopathy Stages (Combined Dataset)")
plt.xlabel("Diagnosis (DR Stage)")
plt.ylabel("Count")
plt.xticks([0, 1, 2, 3, 4], ["No DR", "Mild DR", "Moderate DR", "Severe DR", "Proliferative DR"])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

print("\nLabel Distribution:")
print(combined_label_distribution)

print("\nMissing Values in Dataset:")
print(combined_data.isnull().sum())

combined_label_distribution = combined_data['diagnosis'].value_counts().sort_index()
plt.figure(figsize=(8, 6))
plt.pie(combined_label_distribution.values, labels=["No DR", "Mild DR", "Moderate DR", "Severe DR", "Proliferative DR"], autopct="%1.1f%%", startangle=90)
plt.title("Percentage Distribution of Diabetic Retinopathy Stages (Combined Dataset)")
plt.show()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3662 entries, 0 to 3661
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id_code    3662 non-null   object
#  1   diagnosis  3662 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 57.3+ KB
#
# First Five Rows of the Dataset:
#         id_code  diagnosis
# 0  1ae8c165fd53          2
# 1  1b329a127307          1
# 2  1b32e1d775ea          4
# 3  1b3647865779          0
# 4  1b398c0494d1          0
# Label Distribution:
# diagnosis
# 0    1805
# 1     370
# 2     999
# 3     193
# 4     295
# Name: count, dtype: int64
#
# Missing Values in Dataset:
# id_code      0
# diagnosis    0
# dtype: int64
